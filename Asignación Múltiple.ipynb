# %% [markdown]
# Canal de YouTube [Fneprofesor](https://www.youtube.com/channel/UCu9NQ0CIbWnahmqNbENI2iA)
#
# Explicación del código en el video https://youtu.be/7zQhdPtKyvk

# %%
#Asignación Multiple de variables

a, b, c, d, e = 1, 'data', True, 3.14, None

# %%
print(a,b,c,d,e)

print('hola')
# Out:
# 1 data True 3.14 None
# hola
