# %% [markdown]
# Canal de YouTube [Fneprofesor](https://www.youtube.com/channel/UCu9NQ0CIbWnahmqNbENI2iA)
#
# Explicación del código en el video https://youtu.be/r1GrdkmFfk8

# %%
#Boolean

a = True
b = False

# %%
c = 'true'

# %%
print(a,b)
# Out:
# True False

# %%
d = None # Null
