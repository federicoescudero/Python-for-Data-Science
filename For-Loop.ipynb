# %% [markdown]
# Canal de YouTube [Fneprofesor](https://www.youtube.com/channel/UCu9NQ0CIbWnahmqNbENI2iA)
#
# Explicación del código en el video https://youtu.be/rJyPQLoFKEQ

# %%
#For-Lop Estructura de repetición FOR

for I in range(5) :
  print(I)
print('a')
print('Otro valor')
# Out:
# 0
# 1
# 2
# 3
# 4
# a
# Otro valor
