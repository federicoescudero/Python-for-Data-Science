# %% [markdown]
# Canal de YouTube [Fneprofesor](https://www.youtube.com/channel/UCu9NQ0CIbWnahmqNbENI2iA)
#
# Explicación del código en el video https://youtu.be/rHRskd6taxk

# %%
#Estructura de decisión IF THEN ELSE CONDITIONAL

velocidad = 100

if velocidad > 99 :
  print('La velocidad es muy rápida')
elif velocidad == 99 :
  print('La velocidad es 99')
else :
  print('La velocidad es muy lenta')
# Out:
# La velocidad es muy rápida
