# %% [markdown]
# Canal de YouTube [Fneprofesor](https://www.youtube.com/channel/UCu9NQ0CIbWnahmqNbENI2iA)
#
# Explicación del código en el video https://youtu.be/G3bQfFvssG0

# %% [markdown]
# # Mi Primer programa

# %% [markdown]
# Se asignó la variable data

# %%
data = 'Hola Mundo'

# %% [markdown]
# Mostramos el contenido de la variable data

# %%
print(data)
# Out:
# Hola Mundo
