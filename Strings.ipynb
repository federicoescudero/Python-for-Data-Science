# %% [markdown]
# Canal de YouTube [Fneprofesor](https://www.youtube.com/channel/UCu9NQ0CIbWnahmqNbENI2iA)
#
# Explicación del código en el video https://youtu.be/nlRtZezZtew
#
# Explicación del código en el video https://youtu.be/1BJwnCcnKyY

# %%
# Strings
data = 'Hola Mundo'

print(data)
print(data[5])
print(len(data))

# %%
#Concatenar 
data2 = 'sigamos aprendiendo juntos'

mensaje = data +' '+ data2

print(mensaje)
