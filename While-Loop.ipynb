# %% [markdown]
# Canal de YouTube [Fneprofesor](https://www.youtube.com/channel/UCu9NQ0CIbWnahmqNbENI2iA)
#
# Explicación del código en el video https://youtu.be/nZCX2zLVtXk

# %%
#For-Loop Estructura de repetición FOR

for I in range(10) :
  print(I)

# %%
#While-Loop Estructura de repetición WHILE

I=5
while I < 10 :
  print(I)
  I+=1 #I = I + 1
# Out:
# 5
# 6
# 7
# 8
# 9
